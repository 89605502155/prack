# %%
from PRPlot import PRPlot

# %%
['10$^{'+str(i)+'}$' for i in range(-35,28,7)]
# Out:
# ['10$^{-35}$',
#  '10$^{-28}$',
#  '10$^{-21}$',
#  '10$^{-14}$',
#  '10$^{-7}$',
#  '10$^{0}$',
#  '10$^{7}$',
#  '10$^{14}$',
#  '10$^{21}$']

# %%
a=PRPlot

# %% [markdown]
# from MetrPlot import MetrPlot

# %%
from MetrPlot import MetrPlot

# %%
a=MetrPlot()

# %%
s=a.main([10**i for i in range(0,10)],[1*(10**i) for i in range(0,10)])

# %%
t=PRPlot()

# %%
yy=[0.1,0.2,0.3]
yi=[0.1,0.2,0.35]

# %%
y=t.main(ref=yy,predict=yi,save=False)

# %%
import matplotlib.pyplot as plt

# %%
tt=[10,1,2,3,4,5]
predict=[10,1,0,7,4,5]

# %%
fig, axs = plt.subplots(figsize=(12, 7))
axs.plot(tt,predict,".",color="red",ms=30)
axs.plot(tt,tt,color="blue",lw=3)
axs.set_ylim(ymin=-2,ymax=60)
#axs.set_xlim(xmin=-2,xmax=60)
#axs.set_yticks(np.linspace(1.0, 4.5, num = 8))
axs.set_ylabel("Predicted data" , fontsize=25,labelpad=8)
axs.grid(color="black",linewidth=0.7)
axs.set_xlabel("True data",  fontsize=25,labelpad=15)
axs.set_title("Predict-reference", fontsize=28,loc="center" ,pad=15)
axs.tick_params(which='major', length=10, width=2)
axs.set_xticklabels([i for i in range(-2,12,2)], fontsize=20)
axs.set_yticklabels([i for i in range(-2,12,2)], fontsize=20)
axs.get_xaxis().set_tick_params(direction='in')
axs.get_yaxis().set_tick_params(direction='in')
#plt.savefig('N-PLS1_predict_reference_synthesic_third_shortName.png', format='png', dpi=300)
#plt.savefig("N-PLS1_predict_reference_synthesic_third_shortName.svg", format="svg")
plt.show();
# Out:
# /tmp/ipykernel_13216/3920872911.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_xticklabels([i for i in range(-2,12,2)], fontsize=20)
# /tmp/ipykernel_13216/3920872911.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs.set_yticklabels([i for i in range(-2,12,2)], fontsize=20)

# %%
fig, axs = plt.subplots(figsize=(12, 7))
axs.plot(tt, predict, ".", color="red", ms=30)
axs.plot(tt, tt, color="blue", lw=3)
axs.set_ylim(ymin=-2,ymax=60)
axs.set_xlim(xmin=-2,xmax=10)

lis_x, lis_x_num = ['0','5','10'],[0,5,10]
lis_y, lis_y_num = ['0','5','10'],[0,5,10]

axs.set_xticks(lis_x_num)
axs.set_yticks(lis_y_num)

axs.set_ylabel("Y", fontsize=25, labelpad=8)
axs.grid(color="black", linewidth=0.7)
axs.set_xlabel("x_name", fontsize=25, labelpad=15)
axs.set_title("name_plot", fontsize=28, loc="center", pad=15)
axs.tick_params(which='major', length=10, width=2)

axs.set_xticklabels(lis_x, fontsize=20)
axs.set_yticklabels(lis_y, fontsize=20)

axs.get_xaxis().set_tick_params(direction='in')
axs.get_yaxis().set_tick_params(direction='in')

plt.show()
